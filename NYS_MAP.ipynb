# %%
#Importing libraries to perform analysis
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Electric_Vehicle_Charging_Stations_in_New_York.csv")

# %%
#get the dataframe columns
cols = df.columns 

#print the columns
print(cols)
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'EV Level1 EVSE Num', 'EV Level2 EVSE Num', 'EV DC Fast Count',
#        'EV Other Info', 'EV Network', 'EV Network Web', 'Geocode Status',
#        'Latitude', 'Longitude', 'Date Last Confirmed', 'ID', 'Updated At',
#        'Owner Type Code', 'Federal Agency ID', 'Federal Agency Name',
#        'Open Date', 'EV Connector Types'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Fuel Type Code              object
# Station Name                object
# Street Address              object
# Intersection Directions     object
# City                        object
# State                       object
# ZIP                          int64
# Plus4                      float64
# Station Phone               object
# Status Code                 object
# Expected Date              float64
# Groups With Access Code     object
# Access Days Time            object
# Cards Accepted              object
# EV Level1 EVSE Num         float64
# EV Level2 EVSE Num         float64
# EV DC Fast Count           float64
# EV Other Info              float64
# EV Network                  object
# EV Network Web              object
# Geocode Status              object
# Latitude                   float64
# Longitude                  float64
# Date Last Confirmed         object
# ID                           int64
# Updated At                  object
# Owner Type Code             object
# ...

# %%
df1 = df.set_index("City", drop = False)
df1
# Out:
#              Fuel Type Code                                      Station Name  \
# City
# Orchard Park           ELEC                                         JATC LU41
# Brooklyn               ELEC                                    GE WattStation
# Victor                 ELEC                                   STATION 1 @ VIL
# Ithaca                 ELEC                                    CITY OF ITHACA
# Coeymans               ELEC                                      LANDING PARK
# ...                     ...                                               ...
# New York               ELEC         MPG 10 E 102nd Street - Tesla Destination
# Auburn                 ELEC                                     Lebrun Nissan
# New York               ELEC  GGMC Parking Carnegie Garage - Tesla Destination
# Watervliet             ELEC                                   HUDSON PRESERVE
# New York               ELEC   iPark 455 Central Park West - Tesla Destination
#
# ...

# %%
df2 = df1.drop([ 'Expected Date', 'EV Network Web', 'Street Address',
       'Intersection Directions', 'Plus4', 'Status Code',
       'Groups With Access Code',
       'EV Level1 EVSE Num', 'EV Level2 EVSE Num', 'EV DC Fast Count',
       'EV Other Info','ID', 'Cards Accepted',
       'Owner Type Code', 'Federal Agency ID', 'Federal Agency Name'], axis=1)

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure
import seaborn as sns
plt.figure(figsize=(8,8))
sns.jointplot(x="Latitude",y="Longitude",data=df2,size=7)
plt.ylabel('Longitude')
plt.xlabel('Latitude')
plt.show()
# Out:
# C:\Users\indir\anaconda3\lib\site-packages\seaborn\axisgrid.py:2272: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
