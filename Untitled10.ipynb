# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv("Alternative_Fuel_Stations_in_New_York.csv")

# %%
df.head(5)
# Out:
#   Fuel Type Code     Station Name      Street Address  \
# 0           ELEC        JATC LU41  3546 California Rd
# 1           ELEC   GE WattStation         214  3rd St
# 2           ELEC  STATION 1 @ VIL        70 E Main St
# 3           ELEC   CITY OF ITHACA       118 Dryden Rd
# 4           ELEC     LANDING PARK          70 Main St
#
#          Intersection Directions          City State    ZIP  Plus4  \
# 0                      JATC LU41  Orchard Park    NY  14127    NaN
# 1                            NaN      Brooklyn    NY  11215    NaN
# 2  VICTOR; In lot next to church        Victor    NY  14564    NaN
# 3              DRYDEN; 2nd floor        Ithaca    NY  14850    NaN
# 4                    COEYMANS; -      Coeymans    NY  12045    NaN
#
#   Station Phone Status Code  ...  EV Pricing (French) LPG Nozzle Types  \
# 0  888-758-4389           E  ...                  NaN              NaN
# 1  855-443-3873           E  ...                  NaN              NaN
# 2  888-758-4389           E  ...                  NaN              NaN
# 3  888-758-4389           E  ...                  NaN              NaN
# 4  888-758-4389           E  ...                  NaN              NaN
#
#   Hydrogen Pressures Hydrogen Standards CNG Fill Type Code CNG PSI  \
# 0                NaN                NaN                NaN     NaN
# 1                NaN                NaN                NaN     NaN
# 2                NaN                NaN                NaN     NaN
# 3                NaN                NaN                NaN     NaN
# 4                NaN                NaN                NaN     NaN
#
#   CNG Vehicle Class  LNG Vehicle Class  EV On-Site Renewable Source  \
# 0               NaN                NaN                          NaN
# 1               NaN                NaN                          NaN
# 2               NaN                NaN                          NaN
# 3               NaN                NaN                          NaN
# 4               NaN                NaN                          NaN
#
#                                  Location 1
# 0                  (42.7871971, -78.787821)
# 1                 (40.6753309, -73.9885628)
# 2                 (42.9817554, -77.4083598)
# 3  (42.442141799999995, -76.48611170000001)
# 4           (42.472557, -73.79039590000001)
#
# [5 rows x 65 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1840 entries, 0 to 1839
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    1840 non-null   object
#  1   Station Name                      1840 non-null   object
#  2   Street Address                    1840 non-null   object
#  3   Intersection Directions           807 non-null    object
#  4   City                              1840 non-null   object
#  5   State                             1840 non-null   object
#  6   ZIP                               1840 non-null   int64
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     1828 non-null   object
#  9   Status Code                       1840 non-null   object
#  10  Expected Date                     0 non-null      float64
#  11  Groups With Access Code           1840 non-null   object
#  12  Access Days Time                  1840 non-null   object
#  13  Cards Accepted                    180 non-null    object
#  14  BD Blends                         5 non-null      object
#  15  NG Fill Type Code                 32 non-null     object
#  16  NG PSI                            32 non-null     object
#  17  EV Level1 EVSE Num                10 non-null     float64
#  18  EV Level2 EVSE Num                1597 non-null   float64
#  19  EV DC Fast Count                  130 non-null    float64
#  20  EV Other Info                     0 non-null      float64
#  21  EV Network                        1700 non-null   object
#  22  EV Network Web                    1551 non-null   object
#  23  Geocode Status                    1840 non-null   object
#  24  Latitude                          1840 non-null   float64
#  25  Longitude                         1840 non-null   float64
#  26  Date Last Confirmed               1817 non-null   object
#  27  ID                                1840 non-null   int64
#  28  Updated At                        1840 non-null   object
#  29  Owner Type Code                   1005 non-null   object
#  30  Federal Agency ID                 1 non-null      float64
#  31  Federal Agency Name               1 non-null      object
#  32  Open Date                         970 non-null    object
#  33  Hydrogen Status Link              0 non-null      float64
#  34  NG Vehicle Class                  32 non-null     object
#  35  LPG Primary                       38 non-null     object
#  36  E85 Blender Pump                  65 non-null     object
#  37  EV Connector Types                1700 non-null   object
#  38  Country                           1840 non-null   object
#  39  Intersection Directions (French)  0 non-null      float64
#  40  Access Days Time (French)         0 non-null      float64
#  41  BD Blends (French)                0 non-null      float64
#  42  Groups With Access Code (French)  1840 non-null   object
#  43  Hydrogen is Retail                0 non-null      float64
#  44  Access Code                       1840 non-null   object
#  45  Access Detail Code                182 non-null    object
#  46  Federal Agency Code               1 non-null      object
#  47  Facility Type                     870 non-null    object
#  48  CNG Dispenser Num                 32 non-null     float64
#  49  CNG On-Site Renewable Source      0 non-null      float64
#  50  CNG Total Compression Capacity    20 non-null     float64
#  51  CNG Storage Capacity              9 non-null      float64
#  52  LNG On-Site Renewable Source      0 non-null      float64
#  53  E85 Other Ethanol Blends          0 non-null      float64
#  54  EV Pricing                        1456 non-null   object
#  55  EV Pricing (French)               0 non-null      float64
#  56  LPG Nozzle Types                  34 non-null     object
#  57  Hydrogen Pressures                0 non-null      float64
#  58  Hydrogen Standards                0 non-null      float64
#  59  CNG Fill Type Code                32 non-null     object
#  60  CNG PSI                           32 non-null     object
#  61  CNG Vehicle Class                 32 non-null     object
#  62  LNG Vehicle Class                 0 non-null      float64
#  63  EV On-Site Renewable Source       2 non-null      object
#  64  Location 1                        1840 non-null   object
# dtypes: float64(24), int64(2), object(39)
# memory usage: 934.5+ KB

# %%
data = pd.read_csv('Alternative_Fuel_Stations_in_New_York.csv', sep=',',header=None, index_col =0)

data.plot(kind='bar')
plt.ylabel('Frequency')
plt.xlabel('Words')
plt.title('Title')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8ca1b452d3a8> in <module>
#       1 data = pd.read_csv('Alternative_Fuel_Stations_in_New_York.csv', sep=',',header=None, index_col =0)
#       2
# ----> 3 data.plot(kind='bar')
#       4 plt.ylabel('Frequency')
#       5 plt.xlabel('Words')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot
