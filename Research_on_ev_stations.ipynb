# %%
#Importing libraries to perform analysis
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Electric_Vehicle_Charging_Stations_in_New_York.csv")

# %%
#get the dataframe columns
cols = df.columns 

#print the columns
print(cols)
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'EV Level1 EVSE Num', 'EV Level2 EVSE Num', 'EV DC Fast Count',
#        'EV Other Info', 'EV Network', 'EV Network Web', 'Geocode Status',
#        'Latitude', 'Longitude', 'Date Last Confirmed', 'ID', 'Updated At',
#        'Owner Type Code', 'Federal Agency ID', 'Federal Agency Name',
#        'Open Date', 'EV Connector Types'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Fuel Type Code                                      Station Name  \
# 0           ELEC                                         JATC LU41
# 1           ELEC                                    GE WattStation
# 2           ELEC                                   STATION 1 @ VIL
# 3           ELEC                                    CITY OF ITHACA
# 4           ELEC                                      LANDING PARK
# 5           ELEC                                   GLOVERS PARKING
# 6           ELEC                                   TOWNOFLEWISTON1
# 7           ELEC     Best Western Saranac Lake - Tesla Destination
# 8           ELEC                                   DEFREETSVILLE 1
# 9           ELEC  iPark NYC 88th Street Garage - Tesla Destination
#
#         Street Address                          Intersection Directions  \
# 0   3546 California Rd                                        JATC LU41
# 1          214  3rd St                                              NaN
# ...

# %%
df.dtypes
# Out:
# Fuel Type Code              object
# Station Name                object
# Street Address              object
# Intersection Directions     object
# City                        object
# State                       object
# ZIP                          int64
# Plus4                      float64
# Station Phone               object
# Status Code                 object
# Expected Date              float64
# Groups With Access Code     object
# Access Days Time            object
# Cards Accepted              object
# EV Level1 EVSE Num         float64
# EV Level2 EVSE Num         float64
# EV DC Fast Count           float64
# EV Other Info              float64
# EV Network                  object
# EV Network Web              object
# Geocode Status              object
# Latitude                   float64
# Longitude                  float64
# Date Last Confirmed         object
# ID                           int64
# Updated At                  object
# Owner Type Code             object
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Fuel Type Code                                      Station Name  \
# 0              ELEC                                         JATC LU41
# 1              ELEC                                    GE WattStation
# 2              ELEC                                   STATION 1 @ VIL
# 3              ELEC                                    CITY OF ITHACA
# 4              ELEC                                      LANDING PARK
# ...             ...                                               ...
# 1672           ELEC         MPG 10 E 102nd Street - Tesla Destination
# 1673           ELEC                                     Lebrun Nissan
# 1674           ELEC  GGMC Parking Carnegie Garage - Tesla Destination
# 1675           ELEC                                   HUDSON PRESERVE
# 1676           ELEC   iPark 455 Central Park West - Tesla Destination
#
#           Street Address        Intersection Directions          City State  \
# ...

# %%
count = df['City'].value_counts() 
print(count)
# Out:
# New York          318
# Brooklyn           72
# Rochester          61
# Albany             45
# Buffalo            43
#                  ...
# Henrietta           1
# Au Sable Forks      1
# Margaretville       1
# Bethel              1
# Brooktondale        1
# Name: City, Length: 422, dtype: int64

# %%
count = df['ZIP'].value_counts() 
print(count)
# Out:
# 10019    34
# 12866    33
# 12401    22
# 10016    22
# 14850    21
#          ..
# 12514     1
# 13320     1
# 13323     1
# 13339     1
# 10468     1
# Name: ZIP, Length: 559, dtype: int64

# %%
count = df['EV Connector Types'].value_counts() 
print(count)
# Out:
# J1772                       1094
# J1772 TESLA                  299
# TESLA                        193
# CHADEMO J1772COMBO            38
# J1772COMBO                    11
# CHADEMO J1772                 11
# CHADEMO J1772 J1772COMBO      11
# J1772 NEMA520                  6
# J1772 J1772COMBO               6
# CHADEMO                        4
# NEMA520                        2
# J1772 NEMA515                  1
# J1772 NEMA1450 NEMA520         1
# Name: EV Connector Types, dtype: int64

# %%
# Multi-column frequency count 
count = df.groupby(['ZIP', 'EV Connector Types']).size() 
print(count)
# Out:
# ZIP    EV Connector Types
# 10001  J1772                 3
#        J1772 TESLA           7
# 10002  J1772                 3
#        J1772 TESLA           2
#        TESLA                 1
#                             ..
# 14870  TESLA                 1
# 14881  J1772                 1
# 14886  J1772                 2
# 14901  J1772                 1
#        J1772COMBO            1
# Length: 786, dtype: int64

# %%
# Multi-column frequency count 
count1 = df.groupby(['Status Code']).size() 
print(count1)
# Out:
# Status Code
# E    1677
# dtype: int64

# %%
count = df['EV Network'].value_counts() 
print(count)
# Out:
# ChargePoint Network    697
# Tesla Destination      444
# EV Connect             210
# Non-Networked          133
# Tesla                   48
# Blink Network           41
# GE WattStation          41
# eVgo Network            24
# SemaCharge Network      14
# Greenlots               11
# Electrify America       10
# Volta                    3
# FLO                      1
# Name: EV Network, dtype: int64

# %%
df1 = df

# %%
# import pandas and matplotlib 
import pandas as pd 
import matplotlib.pyplot as plt 
df2 = pd.DataFrame(df, columns = ['City', 'EV Network'] ) 
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
# create histogram for numeric data 
df.hist() 
  
# show plot 
plt.show()

# %%
df2 = df1.drop(['Fuel Type Code', 'Expected Date', 'Station Name','EV Network Web', 'Street Address',
       'Intersection Directions', 'State', 'ZIP', 'Plus4',
       'Station Phone', 'Status Code',
       'Groups With Access Code',
       'EV Level1 EVSE Num', 'EV Level2 EVSE Num', 'EV DC Fast Count',
       'EV Other Info',
       'Latitude', 'Longitude', 'ID', 'Cards Accepted',
       'Owner Type Code', 'Federal Agency ID', 'Federal Agency Name'], axis=1)

# %%
df2.head(10)
# Out:
#                 City                                   Access Days Time  \
# 0       Orchard Park                                     24 hours daily
# 1           Brooklyn                                     24 hours daily
# 2             Victor                                     24 hours daily
# 3             Ithaca                                     24 hours daily
# 4           Coeymans                                     24 hours daily
# 5  Westhampton Beach                                     24 hours daily
# 6           Lewiston                                     24 hours daily
# 7       Saranac Lake                                     24 hours daily
# 8         Rensselaer                                     24 hours daily
# 9           New York  24 hours daily; for customer use only; see val...
#
#             EV Network Geocode Status Date Last Confirmed  \
# 0  ChargePoint Network            GPS          05/27/2020
# ...

# %%
df3 = df2.groupby(['City'])
df3.head()
# Out:
#               City           Access Days Time           EV Network  \
# 0     Orchard Park             24 hours daily  ChargePoint Network
# 1         Brooklyn             24 hours daily       GE WattStation
# 2           Victor             24 hours daily  ChargePoint Network
# 3           Ithaca             24 hours daily  ChargePoint Network
# 4         Coeymans             24 hours daily  ChargePoint Network
# ...            ...                        ...                  ...
# 1656   Dobbs Ferry             24 hours daily  ChargePoint Network
# 1658       Katonah             24 hours daily  ChargePoint Network
# 1666     Johnstown             24 hours daily  ChargePoint Network
# 1667        Goshen             24 hours daily  ChargePoint Network
# 1673        Auburn  Dealership business hours        Non-Networked
#
#      Geocode Status Date Last Confirmed           Updated At   Open Date  \
# 0               GPS          05/27/2020  2020-05-27 09:20:32         NaN
# ...

# %%
df3.dtypes
# Out:
#                  Access Days Time EV Network Geocode Status  \
# City
# Accord                     object     object         object
# Albany                     object     object         object
# Albion                     object     object         object
# Alexandria Bay             object     object         object
# Altamont                   object     object         object
# ...                           ...        ...            ...
# Yorktown Heights           object     object         object
# Yorkville                  object     object         object
# Youngstown                 object     object         object
# clifton park               object     object         object
# new york                   object     object         object
#
#                  Date Last Confirmed Updated At Open Date EV Connector Types
# City
# Accord                        object     object    object             object
# Albany                        object     object    object             object
# ...

# %%
obj_df = df2.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#            City Access Days Time           EV Network Geocode Status  \
# 0  Orchard Park   24 hours daily  ChargePoint Network            GPS
# 1      Brooklyn   24 hours daily       GE WattStation            GPS
# 2        Victor   24 hours daily  ChargePoint Network            GPS
# 3        Ithaca   24 hours daily  ChargePoint Network            GPS
# 4      Coeymans   24 hours daily  ChargePoint Network            GPS
#
#   Date Last Confirmed           Updated At Open Date EV Connector Types
# 0          05/27/2020  2020-05-27 09:20:32       NaN              J1772
# 1          05/15/2020  2020-05-15 10:00:11       NaN              J1772
# 2          05/27/2020  2020-05-27 09:20:32       NaN              J1772
# 3          05/27/2020  2020-05-27 09:20:32       NaN              J1772
# 4          05/27/2020  2020-05-27 09:20:32       NaN              J1772

# %%
obj_df[obj_df.isnull().any(axis=1)]
# Out:
#                   City Access Days Time           EV Network Geocode Status  \
# 0         Orchard Park   24 hours daily  ChargePoint Network            GPS
# 1             Brooklyn   24 hours daily       GE WattStation            GPS
# 2               Victor   24 hours daily  ChargePoint Network            GPS
# 3               Ithaca   24 hours daily  ChargePoint Network            GPS
# 4             Coeymans   24 hours daily  ChargePoint Network            GPS
# ...                ...              ...                  ...            ...
# 1666         Johnstown   24 hours daily  ChargePoint Network            GPS
# 1667            Goshen   24 hours daily  ChargePoint Network            GPS
# 1669  Saratoga Springs   24 hours daily       GE WattStation            GPS
# 1671      White Plains   24 hours daily  ChargePoint Network            GPS
# 1675        Watervliet   24 hours daily  ChargePoint Network            GPS
#
# ...

# %%
obj_df["City"].value_counts()
# Out:
# New York          318
# Brooklyn           72
# Rochester          61
# Albany             45
# Buffalo            43
#                  ...
# Henrietta           1
# Au Sable Forks      1
# Margaretville       1
# Bethel              1
# Brooktondale        1
# Name: City, Length: 422, dtype: int64

# %%
obj_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 1677 non-null   object
#  1   Access Days Time     1677 non-null   object
#  2   EV Network           1677 non-null   object
#  3   Geocode Status       1677 non-null   object
#  4   Date Last Confirmed  1677 non-null   object
#  5   Updated At           1677 non-null   object
#  6   Open Date            842 non-null    object
#  7   EV Connector Types   1677 non-null   object
# dtypes: object(8)
# memory usage: 104.9+ KB

# %%
obj_df["City"] = np.where(obj_df["engine_type"].str.contains("ohc"), 1, other=0)

# %%
# import pandas and matplotlib 
import pandas as pd 
import matplotlib.pyplot as plt 
df2 = pd.DataFrame(df, columns = ['City', 'EV Network'] ) 
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=120, facecolor='w', edgecolor='k')
# create histogram for numeric data 
df.hist() 
  
# show plot 
plt.show()
