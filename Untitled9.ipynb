# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv("Alternative_Fuel_Stations_in_New_York.csv")

# %%
nRowsRead = 100 # specify 'None' if want to read whole file
# alternative-fuel-stations-in-new-york.csv has 1141 rows in reality, but we are only loading/previewing the first 100 rows
df1 = pd.read_csv('Alternative_Fuel_Stations_in_New_York.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'Alternative_Fuel_Stations_in_New_York.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 100 rows and 65 columns

# %%
df.head()
# Out:
#   Fuel Type Code     Station Name      Street Address  \
# 0           ELEC        JATC LU41  3546 California Rd
# 1           ELEC   GE WattStation         214  3rd St
# 2           ELEC  STATION 1 @ VIL        70 E Main St
# 3           ELEC   CITY OF ITHACA       118 Dryden Rd
# 4           ELEC     LANDING PARK          70 Main St
#
#          Intersection Directions          City State    ZIP  Plus4  \
# 0                      JATC LU41  Orchard Park    NY  14127    NaN
# 1                            NaN      Brooklyn    NY  11215    NaN
# 2  VICTOR; In lot next to church        Victor    NY  14564    NaN
# 3              DRYDEN; 2nd floor        Ithaca    NY  14850    NaN
# 4                    COEYMANS; -      Coeymans    NY  12045    NaN
#
#   Station Phone Status Code  ...  EV Pricing (French) LPG Nozzle Types  \
# 0  888-758-4389           E  ...                  NaN              NaN
# 1  855-443-3873           E  ...                  NaN              NaN
# ...

# %%
df.plot(kind='bar')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-5dfd7a0bf7ad> in <module>
# ----> 1 df.plot(kind='his')
#       2
#       3
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     778
#     779         if kind not in self._all_kinds:
# --> 780             raise ValueError(f"{kind} is not a valid plot kind")
#     781
#     782         # The original data structured can be transformed before passed to the
#
# ValueError: his is not a valid plot kind

# %%
plt.matshow(df.corr())
plt.show()

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r' & 'BrBG' are other good diverging colormaps
# Out:
# <style  type="text/css" >
#     #T_30282078_a1e4_11ea_b88b_90324b254934row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_30282078_a1e4_11ea_b88b_90324b254934row0_col1 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_30282078_a1e4_11ea_b88b_90324b254934row0_col2 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_30282078_a1e4_11ea_b88b_90324b254934row0_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_30282078_a1e4_11ea_b88b_90324b254934row0_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_30282078_a1e4_11ea_b88b_90324b254934row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_30282078_a1e4_11ea_b88b_90324b254934row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Read file into a Pandas dataframe
from pandas import DataFrame, read_csv
f = 'Alternative_Fuel_Stations_in_New_York.csv'
df = read_csv(f)
df=df[0:10]
df
# Out:
#   Fuel Type Code                                   Station Name  \
# 0           ELEC                                      JATC LU41
# 1           ELEC                                 GE WattStation
# 2           ELEC                                STATION 1 @ VIL
# 3           ELEC                                 CITY OF ITHACA
# 4           ELEC                                   LANDING PARK
# 5           ELEC                                  NATIONAL GRID
# 6           ELEC                                          RPI 1
# 7           ELEC                                     GARBER ROC
# 8           ELEC                                STONY BROOK UNV
# 9           ELEC  Best Western Saranac Lake - Tesla Destination
#
#         Street Address           Intersection Directions          City State  \
# 0   3546 California Rd                         JATC LU41  Orchard Park    NY
# 1          214  3rd St                               NaN      Brooklyn    NY
# ...

# %%
df_dummies = pd.get_dummies(df['City'])
del df_dummies[df_dummies.columns[-1]]
df_new = pd.concat([df, df_dummies], axis=1)
del df_new['City']

# %%
x = df_new.values

# %%
correlation_matrix = np.corrcoef(x.T)
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-602e22de5fc0> in <module>
# ----> 1 correlation_matrix = np.corrcoef(x.T)
#       2 print(correlation_matrix)
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2524         warnings.warn('bias and ddof have no effect and are deprecated',
#    2525                       DeprecationWarning, stacklevel=3)
# -> 2526     c = cov(x, y, rowvar)
#    2527     try:
#    2528         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2429             w *= aweights
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
# ...
